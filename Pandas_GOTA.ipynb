# %% [markdown]
# <a href="https://colab.research.google.com/github/lovnishverma/Python-Getting-Started/blob/main/Pandas_GOTA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas**
#
# A beginner-friendly, hands-on crash course to master the Pandas library for data analysis.

# %% [markdown]
# **1. Introduction to Pandas**
#
# Pandas is a Python library built for data manipulation, cleaning, analysis, and transformation. It is used heavily in machine learning, data science, and analytics.
#
# **Why Pandas?**
#
# ✔ Load data easily
#
# ✔ Clean messy datasets
#
# ✔ Analyze patterns
#
# ✔ Transform and reshape data
#
# ✔ Handle missing values
#
# ✔ Merge and join multiple datasets

# %% [markdown]
# **Installation** (No need to install in google colab because it's already pre-installed)

# %% [markdown]
# ```
# !pip install pandas
# ```

# %% [markdown]
# **Importing Pandas**

# %%
import pandas as pd

# %% [markdown]
# **Pandas Core Data Structures**

# %% [markdown]
# **1 Series:** A 1D labeled array (like a column in Excel).

# %%
s = pd.Series([10, 20, 30, 40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
series = pd.Series(['ram', 'sita', 'lakshman', 'hanuman'])
print(series)
# Out:
# 0         ram
# 1        sita
# 2    lakshman
# 3     hanuman
# dtype: object

# %% [markdown]
# 2 **DataFrame:** A 2D table with rows and columns.

# %%
data = {
    "Name": ["Amit", "Rahul", "Priya"],
    "Age": [25, 30, 22]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0   Amit   25
# 1  Rahul   30
# 2  Priya   22

# %%
dataf = pd.DataFrame({
    "city": ["Assam", "Delhi", "Pune"],
    "crimerate": [25, 30, 22],
    "population": [255.04, 30.5, 265.62]
})
print(dataf)
# Out:
#     city  crimerate  population
# 0  Assam         25      255.04
# 1  Delhi         30       30.50
# 2   Pune         22      265.62

# %% [markdown]
# **Reading & Writing Data**

# %% [markdown]
# CSV

# %%
df = pd.read_csv("army.csv")  # read_csv() Read krta hai yeh function csv file ko
# df.to_csv("output.csv", index=False)  # Write

# %% [markdown]
# Excel

# %%
# df = pd.read_excel("file.xlsx")

# %% [markdown]
# JSON

# %%
# df = pd.read_json("file.json")

# %% [markdown]
# **Exploring Data**

# %%
df
# Out:
#      name    age   salary
# 0     Raju  32.0  50000.0
# 1   Puneet  34.0  60000.0
# 2      Ram  25.0  35000.0
# 3  Lovnish   NaN  30000.0
# 4     Ravi  28.0      NaN
# 5   Puneet  34.0  60000.0

# %%
df.head() # first 5 rows
# Out:
#      name    age   salary
# 0     Raju  32.0  50000.0
# 1   Puneet  34.0  60000.0
# 2      Ram  25.0  35000.0
# 3  Lovnish   NaN  30000.0
# 4     Ravi  28.0      NaN

# %%
df.head(2) # first 2 rows
# Out:
#     name    age   salary
# 0    Raju  32.0  50000.0
# 1  Puneet  34.0  60000.0

# %%
df.tail() # last 5 rows
# Out:
#      name    age   salary
# 1   Puneet  34.0  60000.0
# 2      Ram  25.0  35000.0
# 3  Lovnish   NaN  30000.0
# 4     Ravi  28.0      NaN
# 5   Puneet  34.0  60000.0

# %%
print(df.shape) # rows, columns  # yeh datframe ki shape btata hai
# Out:
# (6, 3)

# %%
df.columns # column names
# Out:
# Index(['name ', 'age', 'salary'], dtype='object')

# %%
df.dtypes # DATA KA TYPE BTATA HAI
# Out:
# name       object
# age       float64
# salary    float64
# dtype: object

# %%
df.info() # data types and  missing values pata chal jati hai
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   age     5 non-null      float64
#  2   salary  5 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 276.0+ bytes

# %%
df.describe() # Statistics Summary # but only for numeric columns
# Out:
#              age        salary
# count   5.000000      5.000000
# mean   30.600000  47000.000000
# std     3.974921  13964.240044
# min    25.000000  30000.000000
# 25%    28.000000  35000.000000
# 50%    32.000000  50000.000000
# 75%    34.000000  60000.000000
# max    34.000000  60000.000000

# %% [markdown]
# # Selecting data

# %%
df
# Out:
#      name    age   salary
# 0     Raju  32.0  50000.0
# 1   Puneet  34.0  60000.0
# 2      Ram  25.0  35000.0
# 3  Lovnish   NaN  30000.0
# 4     Ravi  28.0      NaN
# 5   Puneet  34.0  60000.0

# %%
#Row Slicing
df[1:4] # rows 1 to 3   # end index is exclusive
# Out:
#      name    age   salary
# 1   Puneet  34.0  60000.0
# 2      Ram  25.0  35000.0
# 3  Lovnish   NaN  30000.0

# %%
df
# Out:
#      name    age   salary
# 0     Raju  32.0  50000.0
# 1   Puneet  34.0  60000.0
# 2      Ram  25.0  35000.0
# 3  Lovnish   NaN  30000.0
# 4     Ravi  28.0      NaN
# 5   Puneet  34.0  60000.0

# %%
df.iloc[:, :]  # rows, columns
# All the rows and all the columns
# Out:
#      name    age   salary
# 0     Raju  32.0  50000.0
# 1   Puneet  34.0  60000.0
# 2      Ram  25.0  35000.0
# 3  Lovnish   NaN  30000.0
# 4     Ravi  28.0      NaN
# 5   Puneet  34.0  60000.0

# %%
df.iloc[:, 1] # All the rows, column at the 1st index only
# Out:
# 0    32.0
# 1    34.0
# 2    25.0
# 3     NaN
# 4    28.0
# 5    34.0
# Name: age, dtype: float64

# %%
df.iloc[0, :] # 1st row , all the columns
# Out:
# name         Raju
# age          32.0
# salary    50000.0
# Name: 0, dtype: object

# %% [markdown]
# # Selecting the data

# %%
df[1:4] # Rows 1 to 3   # end index is exclusive
# Out:
#      name    age   salary
# 1   Puneet  34.0  60000.0
# 2      Ram  25.0  35000.0
# 3  Lovnish   NaN  30000.0

# %%
df.iloc[3]
# Out:
# name      Lovnish
# age           NaN
# salary    30000.0
# Name: 3, dtype: object

# %%
df.iloc[1:3] # Rows 1 to 2   # end index is exclusive
# Out:
#     name    age   salary
# 1  Puneet  34.0  60000.0
# 2     Ram  25.0  35000.0

# %%
df.columns
# Out:
# Index(['name ', 'age', 'salary'], dtype='object')

# %%
df.loc[:, 'age']  # rows, columns
# Out:
# 0    32.0
# 1    34.0
# 2    25.0
# 3     NaN
# 4    28.0
# 5    34.0
# Name: age, dtype: float64

# %%
df.loc[:, ['age', 'salary']]
# Out:
#     age   salary
# 0  32.0  50000.0
# 1  34.0  60000.0
# 2  25.0  35000.0
# 3   NaN  30000.0
# 4  28.0      NaN
# 5  34.0  60000.0

# %% [markdown]
# # data sorting

# %%
df.sort_values(by='age', ascending=True)
# Out:
#      name    age   salary
# 2      Ram  25.0  35000.0
# 4     Ravi  28.0      NaN
# 0     Raju  32.0  50000.0
# 1   Puneet  34.0  60000.0
# 5   Puneet  34.0  60000.0
# 3  Lovnish   NaN  30000.0

# %% [markdown]
# # Creating a new column

# %%
#creating a new column
df['new_column'] = df['age'] + df['salary']

# %%
df
# Out:
#      name    age   salary  new_column
# 0     Raju  32.0  50000.0     50032.0
# 1   Puneet  34.0  60000.0     60034.0
# 2      Ram  25.0  35000.0     35025.0
# 3  Lovnish   NaN  30000.0         NaN
# 4     Ravi  28.0      NaN         NaN
# 5   Puneet  34.0  60000.0     60034.0

# %%
df['is_poor'] = df['salary'] < 40000

# %%
df
# Out:
#      name    age   salary  new_column  is_poor
# 0     Raju  32.0  50000.0     50032.0    False
# 1   Puneet  34.0  60000.0     60034.0    False
# 2      Ram  25.0  35000.0     35025.0     True
# 3  Lovnish   NaN  30000.0         NaN     True
# 4     Ravi  28.0      NaN         NaN    False
# 5   Puneet  34.0  60000.0     60034.0    False

# %%
df.groupby('age')['salary'].mean()
# Out:
# age
# 25.0    35000.0
# 28.0        NaN
# 32.0    50000.0
# 34.0    60000.0
# Name: salary, dtype: float64

# %%
df
# Out:
#      name    age   salary  new_column  is_poor
# 0     Raju  32.0  50000.0     50032.0    False
# 1   Puneet  34.0  60000.0     60034.0    False
# 2      Ram  25.0  35000.0     35025.0     True
# 3  Lovnish   NaN  30000.0         NaN     True
# 4     Ravi  28.0      NaN         NaN    False
# 5   Puneet  34.0  60000.0     60034.0    False

# %% [markdown]
# # Rename a column

# %%
df.rename(columns={'is_poor': 'low_salary'}, inplace=True)

# %%
df
# Out:
#      name    age   salary  new_column  low_salary
# 0     Raju  32.0  50000.0     50032.0       False
# 1   Puneet  34.0  60000.0     60034.0       False
# 2      Ram  25.0  35000.0     35025.0        True
# 3  Lovnish   NaN  30000.0         NaN        True
# 4     Ravi  28.0      NaN         NaN       False
# 5   Puneet  34.0  60000.0     60034.0       False

# %% [markdown]
# # Handling Duplicate Values

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
# Droping duplicate value
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      name    age   salary  new_column  low_salary
# 0     Raju  32.0  50000.0     50032.0       False
# 1   Puneet  34.0  60000.0     60034.0       False
# 2      Ram  25.0  35000.0     35025.0        True
# 3  Lovnish   NaN  30000.0         NaN        True
# 4     Ravi  28.0      NaN         NaN       False

# %% [markdown]
# # Handling missing (null) values

# %%
df.isnull().sum()
# Out:
# name          0
# age           1
# salary        1
# new_column    2
# low_salary    0
# dtype: int64

# %%
df
# Out:
#      name    age   salary  new_column  low_salary
# 0     Raju  32.0  50000.0     50032.0       False
# 1   Puneet  34.0  60000.0     60034.0       False
# 2      Ram  25.0  35000.0     35025.0        True
# 3  Lovnish   NaN  30000.0         NaN        True
# 4     Ravi  28.0      NaN         NaN       False

# %%
#droping missing values
df.dropna()
# Out:
#     name    age   salary  new_column  low_salary
# 0    Raju  32.0  50000.0     50032.0       False
# 1  Puneet  34.0  60000.0     60034.0       False
# 2     Ram  25.0  35000.0     35025.0        True

# %%
df
# Out:
#      name    age   salary  new_column  low_salary
# 0     Raju  32.0  50000.0     50032.0       False
# 1   Puneet  34.0  60000.0     60034.0       False
# 2      Ram  25.0  35000.0     35025.0        True
# 3  Lovnish   NaN  30000.0         NaN        True
# 4     Ravi  28.0      NaN         NaN       False

# %% [markdown]
# # filling missing values

# %%
# df.fillna(25)

# %%
df['age'].fillna(df['age'].mean(), inplace=True)
df['age'].fillna(df['salary'].median(), inplace=True)
# df['age'].fillna(df['name'].mode(), inplace=True)
# Out:
# /tmp/ipython-input-191618448.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].mean(), inplace=True)
# /tmp/ipython-input-191618448.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['salary'].median(), inplace=True)

# %%
# filling missing name column
# df['name'].fillna('Unknown', inplace=True)

# %%
# fillng most occoured name in name column
# df['name'].fillna(df['name'].mode()[0], inplace=True)

# %%
df
# Out:
#      name     age   salary  new_column  low_salary
# 0     Raju  32.00  50000.0     50032.0       False
# 1   Puneet  34.00  60000.0     60034.0       False
# 2      Ram  25.00  35000.0     35025.0        True
# 3  Lovnish  29.75  30000.0         NaN        True
# 4     Ravi  28.00      NaN         NaN       False

# %%
# df = df.ffill() # forward fill
# df = df.bfill() # backward fill

# %% [markdown]
# # Loop through rows

# %%
# Loop through rows
for index, row in df.iterrows():
    print(f"{row['age']} has Salary {row['salary']}")
# Out:
# 32.0 has Salary 50000.0
# 34.0 has Salary 60000.0
# 25.0 has Salary 35000.0
# 29.75 has Salary 30000.0
# 28.0 has Salary nan

# %%
df
# Out:
#      name     age   salary  new_column  low_salary
# 0     Raju  32.00  50000.0     50032.0       False
# 1   Puneet  34.00  60000.0     60034.0       False
# 2      Ram  25.00  35000.0     35025.0        True
# 3  Lovnish  29.75  30000.0         NaN        True
# 4     Ravi  28.00      NaN         NaN       False

# %% [markdown]
# # Saving (Exporting) Dataset

# %%
df.to_csv("armynewww.csv", index=False)
