# %% [markdown]
# <a href="https://colab.research.google.com/github/lovnishverma/Python-Getting-Started/blob/main/LFM2_2_6B_Exp_GGUF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LFM2-2.6B-Exp-GGUF**

# %% [markdown]
# LFM2 is a new generation of hybrid models developed by **Liquid AI**, specifically designed for edge AI and on-device deployment. It sets a new standard in terms of quality, speed, and memory efficiency.
#
# Find more details in the original model card: https://huggingface.co/LiquidAI/LFM2-2.6B-Exp

# %% [markdown]
# **Source:** https://huggingface.co/LiquidAI/LFM2-2.6B-Exp-GGUF

# %%
# !pip install -U llama-cpp-python -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 MB 12.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/LiquidAI/LFM2-2.6B-Exp-GGUF
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/LiquidAI/LFM2-2.6B-Exp-GGUF)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# !pip install llama-cpp-python

from llama_cpp import Llama

llm = Llama.from_pretrained(
	repo_id="LiquidAI/LFM2-2.6B-Exp-GGUF",
	filename="LFM2-2.6B-Exp-F16.gguf",
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:103: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# ./LFM2-2.6B-Exp-F16.gguf:   0%|          | 0.00/5.41G [00:00<?, ?B/s]
# ...

# %%
llm.create_chat_completion(
	messages = [
		{
			"role": "user",
			"content": "What is the capital of France?"
		}
	]
)
# Out:
# llama_perf_context_print:        load time =    2674.69 ms
# llama_perf_context_print: prompt eval time =    2674.31 ms /    16 tokens (  167.14 ms per token,     5.98 tokens per second)
# llama_perf_context_print:        eval time =  125057.48 ms /   232 runs   (  539.04 ms per token,     1.86 tokens per second)
# llama_perf_context_print:       total time =  127909.07 ms /   248 tokens
# llama_perf_context_print:    graphs reused =        231
# {'id': 'chatcmpl-20d2dad5-1a97-48f3-93c7-d746ebfe2c93',
#  'object': 'chat.completion',
#  'created': 1776677881,
#  'model': '/root/.cache/huggingface/hub/models--LiquidAI--LFM2-2.6B-Exp-GGUF/snapshots/7d9bef941a2642e1d00967564fd55e1dcecf0d6a/./LFM2-2.6B-Exp-F16.gguf',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
# ...

# %%
llm.create_chat_completion(
	messages = [
		{
			"role": "user",
			"content": "What is NIELIT?"
		}
	]
)
# Out:
# Llama.generate: 6 prefix-match found but partial kv removal not supported, re-evaluating full prompt
# llama_perf_context_print:        load time =    2674.69 ms
# llama_perf_context_print: prompt eval time =    2512.99 ms /    15 tokens (  167.53 ms per token,     5.97 tokens per second)
# llama_perf_context_print:        eval time =  215633.37 ms /   409 runs   (  527.22 ms per token,     1.90 tokens per second)
# llama_perf_context_print:       total time =  218541.24 ms /   424 tokens
# llama_perf_context_print:    graphs reused =        407
# {'id': 'chatcmpl-c9469c27-59bb-4ca2-8e0b-7c5d3c2cb5c4',
#  'object': 'chat.completion',
#  'created': 1776678111,
#  'model': '/root/.cache/huggingface/hub/models--LiquidAI--LFM2-2.6B-Exp-GGUF/snapshots/7d9bef941a2642e1d00967564fd55e1dcecf0d6a/./LFM2-2.6B-Exp-F16.gguf',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
# ...
