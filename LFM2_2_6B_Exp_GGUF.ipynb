# %% [markdown]
# <a href="https://colab.research.google.com/github/lovnishverma/Python-Getting-Started/blob/main/LFM2_2_6B_Exp_GGUF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LFM2-2.6B-Exp-GGUF**

# %% [markdown]
# LFM2 is a new generation of hybrid models developed by **Liquid AI**, specifically designed for edge AI and on-device deployment. It sets a new standard in terms of quality, speed, and memory efficiency.
#
# Find more details in the original model card: https://huggingface.co/LiquidAI/LFM2-2.6B-Exp

# %% [markdown]
# **Source:** https://huggingface.co/LiquidAI/LFM2-2.6B-Exp-GGUF

# %%
# !pip install -U llama-cpp-python -q

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/LiquidAI/LFM2-2.6B-Exp-GGUF
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/LiquidAI/LFM2-2.6B-Exp-GGUF)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# !pip install llama-cpp-python

from llama_cpp import Llama

llm = Llama.from_pretrained(
	repo_id="LiquidAI/LFM2-2.6B-Exp-GGUF",
	filename="LFM2-2.6B-Exp-F16.gguf",
)

# %%
llm.create_chat_completion(
	messages = [
		{
			"role": "user",
			"content": "What is the capital of India?"
		}
	]
)
# Out:
# llama_perf_context_print:        load time =    2228.53 ms
# llama_perf_context_print: prompt eval time =    2228.07 ms /    16 tokens (  139.25 ms per token,     7.18 tokens per second)
# llama_perf_context_print:        eval time =  181813.94 ms /   347 runs   (  523.96 ms per token,     1.91 tokens per second)
# llama_perf_context_print:       total time =  184355.15 ms /   363 tokens
# llama_perf_context_print:    graphs reused =        345
# {'id': 'chatcmpl-d6b64ce4-0ab4-4ff3-8e29-feb1d6152bbc',
#  'object': 'chat.completion',
#  'created': 1776684157,
#  'model': '/root/.cache/huggingface/hub/models--LiquidAI--LFM2-2.6B-Exp-GGUF/snapshots/7d9bef941a2642e1d00967564fd55e1dcecf0d6a/./LFM2-2.6B-Exp-F16.gguf',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
#     'content': "<think>\nOkay, so the question is asking for the capital of India. Let me think about this.\n\nI remember that India is a large country in South Asia, and like many countries, it has a capital city where the government is based. But I'm not sure if I can recall the exact name. Let me try to think of some key points.\n\nI know that New Delhi is a major city in India. But is it the capital? I think so, but I should verify. Sometimes people confuse it with other cities like Mumbai or Kolkata, which are big cities but not the capital. \n\nWait, maybe I can recall some facts. The Indian government is located there, and it's where important political decisions are made. Also, the Rashtrapati Bhavan, which is the President's residence, is in New Delhi. \n\nI should also consider if there's any chance of confusion with other countries. For example, sometimes people mix up capitals of nearby countries. But in this case, I'm pretty confident that New Delhi is the correct answer. \n\nLet me check if there are any recent changes. I don't think so; capitals don't change often. So, I can conclude that the capital of India is New Delhi.\n</think>The capital of India is **New Delhi**. \n\nNew Delhi serves as the political and administrative center of the country, housing key government institutions such as the Parliament of India, the President's residence (Rashtrapati Bhavan), and the Supreme Court. It is distinct from Delhi, which is the larger historical city within the National Capital Territory of Delhi. \n\n**Answer:** New Delhi."},
#    'logprobs': None,
#    'finish_reason': 'stop'}],
#  'usage': {'prompt_tokens': 16, 'completion_tokens': 347, 'total_tokens': 363}}
