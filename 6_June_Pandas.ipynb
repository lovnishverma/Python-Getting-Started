# %% [markdown]
# <a href="https://colab.research.google.com/github/lovnishverma/Python-Getting-Started/blob/main/6_June_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive/datasets
# Out:
# cleaned_testdata.csv  testdata.csv

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/datasets/testdata.csv')

df
# Out:
#          rank discipline  phd  service     sex    salary
# 0        Prof          B   56     49.0    Male  186960.0
# 1        Prof          A   12      6.0    Male   93000.0
# 2         NaN          A   23     20.0    Male  110515.0
# 3        Prof          A   40     31.0     NaN  131205.0
# 4        Prof          B   20      NaN    Male  104800.0
# ..        ...        ...  ...      ...     ...       ...
# 75       Prof          B   18     10.0  Female  105450.0
# 76  AssocProf          B   19      6.0  Female  104542.0
# 77       Prof          B   17     17.0  Female  124312.0
# 78       Prof          A   28     14.0  Female  109954.0
# 79       Prof          A   23     15.0  Female  109646.0
#
# [80 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.head(1)
# Out:
#    rank discipline  phd  service   sex    salary
# 0  Prof          B   56     49.0  Male  186960.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        79 non-null     object
#  1   discipline  79 non-null     object
#  2   phd         80 non-null     int64
#  3   service     79 non-null     float64
#  4   sex         79 non-null     object
#  5   salary      79 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.9+ KB

# %%
df.describe()
# Out:
#              phd    service         salary
# count  80.000000  79.000000      79.000000
# mean   19.450000  14.860759  107315.886076
# std    12.516217  12.179990   27596.271520
# min     1.000000   0.000000   57800.000000
# 25%    10.000000   4.500000   88000.000000
# 50%    18.000000  14.000000  104542.000000
# 75%    27.250000  20.500000  126300.000000
# max    56.000000  51.000000  186960.000000

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex    salary
# 0  Prof          B   56     49.0  Male  186960.0
# 1  Prof          A   12      6.0  Male   93000.0
# 2   NaN          A   23     20.0  Male  110515.0
# 3  Prof          A   40     31.0   NaN  131205.0
# 4  Prof          B   20      NaN  Male  104800.0

# %%
# df.iloc[:, :]

# print(df[1:10:2]) #start:stop:step

df.iloc[:, 0:5] #rows , columns
# Out:
#          rank discipline  phd  service     sex
# 0        Prof          B   56     49.0    Male
# 1        Prof          A   12      6.0    Male
# 2         NaN          A   23     20.0    Male
# 3        Prof          A   40     31.0     NaN
# 4        Prof          B   20      NaN    Male
# ..        ...        ...  ...      ...     ...
# 75       Prof          B   18     10.0  Female
# 76  AssocProf          B   19      6.0  Female
# 77       Prof          B   17     17.0  Female
# 78       Prof          A   28     14.0  Female
# 79       Prof          A   23     15.0  Female
#
# [80 rows x 5 columns]

# %%
# df.loc[:, ['rank', 'service']]  # All rows, column 'phd'
# df.loc[0:2, ['rank', 'service']]

# %%
# print(df['rank'])  # Selecting a single column
df[['phd', 'service']]  # Selecting multiple columns
# Out:
#     phd  service
# 0    56     49.0
# 1    12      6.0
# 2    23     20.0
# 3    40     31.0
# 4    20      NaN
# ..  ...      ...
# 75   18     10.0
# 76   19      6.0
# 77   17     17.0
# 78   28     14.0
# 79   23     15.0
#
# [80 rows x 2 columns]

# %%
df[df['service'] > 45]
# Out:
#     rank discipline  phd  service   sex    salary
# 0   Prof          B   56     49.0  Male  186960.0
# 10  Prof          A   51     51.0  Male   57800.0

# %%
print(df.sort_values(by='service'))
# Out:
#         rank discipline  phd  service     sex    salary
# 13  AsstProf          B    1      0.0    Male   88000.0
# 14  AsstProf          B    1      0.0    Male   88000.0
# 25  AsstProf          A    2      0.0    Male   85000.0
# 19  AsstProf          B    4      0.0    Male   92000.0
# 54      Prof          A   12      0.0  Female  105000.0
# ..       ...        ...  ...      ...     ...       ...
# 29      Prof          A   45     43.0    Male  155865.0
# 38      Prof          B   45     45.0    Male  146856.0
# 0       Prof          B   56     49.0    Male  186960.0
# 10      Prof          A   51     51.0    Male   57800.0
# 4       Prof          B   20      NaN    Male  104800.0
#
# [80 rows x 6 columns]

# %%
df['is_senior'] = df['rank'] == 'Prof'  # Example boolean logic



print(df[['rank', 'is_senior']])
# Out:
#          rank  is_senior
# 0        Prof       True
# 1        Prof       True
# 2         NaN      False
# 3        Prof       True
# 4        Prof       True
# ..        ...        ...
# 75       Prof       True
# 76  AssocProf      False
# 77       Prof       True
# 78       Prof       True
# 79       Prof       True
#
# [80 rows x 2 columns]

# %%
# df

#finding duplicates
df.duplicated().sum()



df.drop_duplicates()

df.duplicated().sum()


df.to_csv('cleaned_testdata.csv')

# %%
data = pd.read_csv('cleaned_testdata.csv')

data.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (80, 7)

# %%
df.isnull().sum()
# Out:
# rank          1
# discipline    1
# phd           0
# service       1
# sex           1
# salary        1
# is_senior     0
# dtype: int64

# %%
df['salary'] = df['salary'].fillna(df['salary'].mean())

# %%
df.isnull().sum()
# Out:
# rank          1
# discipline    1
# phd           0
# service       1
# sex           1
# salary        0
# is_senior     0
# dtype: int64

# %%
df.dropna(axis=0, inplace=True)

# %%
df
# Out:
#          rank discipline  phd  service     sex    salary  is_senior
# 0        Prof          B   56     49.0    Male  186960.0       True
# 1        Prof          A   12      6.0    Male   93000.0       True
# 5        Prof          A   20     20.0    Male  122400.0       True
# 6   AssocProf          A   20     17.0    Male   81285.0      False
# 7        Prof          A   18     18.0    Male  126300.0       True
# ..        ...        ...  ...      ...     ...       ...        ...
# 75       Prof          B   18     10.0  Female  105450.0       True
# 76  AssocProf          B   19      6.0  Female  104542.0      False
# 77       Prof          B   17     17.0  Female  124312.0       True
# 78       Prof          A   28     14.0  Female  109954.0       True
# 79       Prof          A   23     15.0  Female  109646.0       True
#
# [76 rows x 7 columns]

# %%
print("\n Missing values after cleaning:")
print(df.isnull().sum())
# Out:
#  Missing values after cleaning:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# is_senior     0
# dtype: int64

# %%
df
# Out:
#          rank discipline  phd  service     sex    salary  is_senior
# 0        Prof          B   56     49.0    Male  186960.0       True
# 1        Prof          A   12      6.0    Male   93000.0       True
# 5        Prof          A   20     20.0    Male  122400.0       True
# 6   AssocProf          A   20     17.0    Male   81285.0      False
# 7        Prof          A   18     18.0    Male  126300.0       True
# ..        ...        ...  ...      ...     ...       ...        ...
# 75       Prof          B   18     10.0  Female  105450.0       True
# 76  AssocProf          B   19      6.0  Female  104542.0      False
# 77       Prof          B   17     17.0  Female  124312.0       True
# 78       Prof          A   28     14.0  Female  109954.0       True
# 79       Prof          A   23     15.0  Female  109646.0       True
#
# [76 rows x 7 columns]

# %%
df.to_csv('/content/drive/MyDrive/datasets/cleaned_testdata.csv')
